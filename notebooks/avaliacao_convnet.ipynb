# %%
import pandas as pd
from sklearn.metrics import classification_report

# %%
df_y = pd.read_csv("../execucao/convnet_test_preds.csv")
df_loss = pd.read_csv("../execucao/convnet_loss.csv")

# %%
y = df.y_true.values
y_pred = df.y_pred.values

# %%
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.52      0.55       470
#          1.0       0.59      0.66      0.62       490
#
#     accuracy                           0.59       960
#    macro avg       0.59      0.59      0.59       960
# weighted avg       0.59      0.59      0.59       960

# %%
df_loss[["train_loss", "val_loss"]].plot()
# Out:
# <AxesSubplot: >

# %%
df_loss[["train_acc", "val_acc"]].plot()
# Out:
# <AxesSubplot: >
